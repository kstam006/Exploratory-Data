# %% [markdown]
# <a href="https://colab.research.google.com/github/kstam006/Exploratory-Data/blob/master/Project_Milestone_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as pd
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/mackinitup/projectmilestone3/master/globalstats%20CSV.csv")

# %%
df.head()
# Out:
#   States and Provinces        Unnamed: 1  Revised June 23, 2014  \
# 0             #isocode          Location  Expenditures-Academic
# 1                CA-AB           Alberta                    NaN
# 2                CA-BC  British Columbia                    NaN
# 3                CA-MB          Manitoba                    NaN
# 4                CA-NB     New Brunswick                    NaN
#
#                      Unnamed: 3                  Unnamed: 4  \
# 0  Expenditures-Academic-Source  Expenditures-Academic-Year
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
#
#               Unnamed: 5                    Unnamed: 6  \
# 0  Expenditures-National  Expenditures-National-Source
# 1                    NaN                           NaN
# ...

# %%
df = df.drop('Unnamed: 6', 1)
df.head()
# Out:
#   States and Provinces        Unnamed: 1  Revised June 23, 2014  \
# 0             #isocode          Location  Expenditures-Academic
# 1                CA-AB           Alberta                    NaN
# 2                CA-BC  British Columbia                    NaN
# 3                CA-MB          Manitoba                    NaN
# 4                CA-NB     New Brunswick                    NaN
#
#                      Unnamed: 3                  Unnamed: 4  \
# 0  Expenditures-Academic-Source  Expenditures-Academic-Year
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
#
#               Unnamed: 5                  Unnamed: 7           Unnamed: 8  \
# 0  Expenditures-National  Expenditures-National-Year  Expenditures-Public
# ...

# %%
df = df.drop(['Unnamed: 7', 'Unnamed: 104', 'Unnamed: 105', 'Unnamed: 106', 'Unnamed: 107', 'Unnamed: 108'], 1)
df.head()
# Out:
#   States and Provinces        Unnamed: 1  Revised June 23, 2014  \
# 0             #isocode          Location  Expenditures-Academic
# 1                CA-AB           Alberta                    NaN
# 2                CA-BC  British Columbia                    NaN
# 3                CA-MB          Manitoba                    NaN
# 4                CA-NB     New Brunswick                    NaN
#
#                      Unnamed: 3                  Unnamed: 4  \
# 0  Expenditures-Academic-Source  Expenditures-Academic-Year
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
#
#               Unnamed: 5           Unnamed: 8                  Unnamed: 9  \
# 0  Expenditures-National  Expenditures-Public  Expenditures-Public-Source
# ...

# %%
df = df.drop(['Unnamed: 99', 'Unnamed: 100', 'Unnamed: 101', 'Unnamed: 102', 'Unnamed: 103', 'Unnamed: 109', 'Unnamed: 110', 'Unnamed: 111', 'Unnamed: 112', 'Unnamed: 113'], 1)
df.head()
# Out:
#   States and Provinces        Unnamed: 1  Revised June 23, 2014  \
# 0             #isocode          Location  Expenditures-Academic
# 1                CA-AB           Alberta                    NaN
# 2                CA-BC  British Columbia                    NaN
# 3                CA-MB          Manitoba                    NaN
# 4                CA-NB     New Brunswick                    NaN
#
#                      Unnamed: 3                  Unnamed: 4  \
# 0  Expenditures-Academic-Source  Expenditures-Academic-Year
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
#
#               Unnamed: 5           Unnamed: 8                  Unnamed: 9  \
# 0  Expenditures-National  Expenditures-Public  Expenditures-Public-Source
# ...

# %%
df = df.drop(['Unnamed: 89', 'Unnamed: 90', 'Unnamed: 91', 'Unnamed: 92', 'Unnamed: 93', 'Unnamed: 94', 'Unnamed: 95', 'Unnamed: 96', 'Unnamed: 97', 'Unnamed: 98'], 1)
df.head()
# Out:
#   States and Provinces        Unnamed: 1  Revised June 23, 2014  \
# 0             #isocode          Location  Expenditures-Academic
# 1                CA-AB           Alberta                    NaN
# 2                CA-BC  British Columbia                    NaN
# 3                CA-MB          Manitoba                    NaN
# 4                CA-NB     New Brunswick                    NaN
#
#                      Unnamed: 3                  Unnamed: 4  \
# 0  Expenditures-Academic-Source  Expenditures-Academic-Year
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
#
#               Unnamed: 5           Unnamed: 8                  Unnamed: 9  \
# 0  Expenditures-National  Expenditures-Public  Expenditures-Public-Source
# ...

# %%
df = df.drop(['Unnamed: 86', 'Unnamed: 87', 'Unnamed: 88'], 1)
df.head()
# Out:
#   States and Provinces        Unnamed: 1  Revised June 23, 2014  \
# 0             #isocode          Location  Expenditures-Academic
# 1                CA-AB           Alberta                    NaN
# 2                CA-BC  British Columbia                    NaN
# 3                CA-MB          Manitoba                    NaN
# 4                CA-NB     New Brunswick                    NaN
#
#                      Unnamed: 3                  Unnamed: 4  \
# 0  Expenditures-Academic-Source  Expenditures-Academic-Year
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
#
#               Unnamed: 5           Unnamed: 8                  Unnamed: 9  \
# 0  Expenditures-National  Expenditures-Public  Expenditures-Public-Source
# ...

# %%
df = df.drop(['Unnamed: 5', 'Unnamed: 11', 'Unnamed: 12'], 1)
df.head()
# Out:
#   States and Provinces        Unnamed: 1  Revised June 23, 2014  \
# 0             #isocode          Location  Expenditures-Academic
# 1                CA-AB           Alberta                    NaN
# 2                CA-BC  British Columbia                    NaN
# 3                CA-MB          Manitoba                    NaN
# 4                CA-NB     New Brunswick                    NaN
#
#                      Unnamed: 3                  Unnamed: 4  \
# 0  Expenditures-Academic-Source  Expenditures-Academic-Year
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
#
#             Unnamed: 8                  Unnamed: 9               Unnamed: 10  \
# 0  Expenditures-Public  Expenditures-Public-Source  Expenditures-Public-Year
# ...

# %%
df = df.drop(['Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15'], 1)
df.head()
# Out:
#   States and Provinces        Unnamed: 1  Revised June 23, 2014  \
# 0             #isocode          Location  Expenditures-Academic
# 1                CA-AB           Alberta                    NaN
# 2                CA-BC  British Columbia                    NaN
# 3                CA-MB          Manitoba                    NaN
# 4                CA-NB     New Brunswick                    NaN
#
#                      Unnamed: 3                  Unnamed: 4  \
# 0  Expenditures-Academic-Source  Expenditures-Academic-Year
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
#
#             Unnamed: 8                  Unnamed: 9               Unnamed: 10  \
# 0  Expenditures-Public  Expenditures-Public-Source  Expenditures-Public-Year
# ...

# %%
df = df.drop(['Unnamed: 16'], 1)
df.head()
# Out:
#   States and Provinces        Unnamed: 1  Revised June 23, 2014  \
# 0             #isocode          Location  Expenditures-Academic
# 1                CA-AB           Alberta                    NaN
# 2                CA-BC  British Columbia                    NaN
# 3                CA-MB          Manitoba                    NaN
# 4                CA-NB     New Brunswick                    NaN
#
#                      Unnamed: 3                  Unnamed: 4  \
# 0  Expenditures-Academic-Source  Expenditures-Academic-Year
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
#
#             Unnamed: 8                  Unnamed: 9               Unnamed: 10  \
# 0  Expenditures-Public  Expenditures-Public-Source  Expenditures-Public-Year
# ...

# %%
df = df.drop(['Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 35'], 1)
df.head()
# Out:
#   States and Provinces        Unnamed: 1  Revised June 23, 2014  \
# 0             #isocode          Location  Expenditures-Academic
# 1                CA-AB           Alberta                    NaN
# 2                CA-BC  British Columbia                    NaN
# 3                CA-MB          Manitoba                    NaN
# 4                CA-NB     New Brunswick                    NaN
#
#                      Unnamed: 3                  Unnamed: 4  \
# 0  Expenditures-Academic-Source  Expenditures-Academic-Year
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
#
#             Unnamed: 8                  Unnamed: 9               Unnamed: 10  \
# 0  Expenditures-Public  Expenditures-Public-Source  Expenditures-Public-Year
# ...

# %%
df = df.drop(['Unnamed: 36', 'Unnamed: 37', 'Unnamed: 50', 'Unnamed: 51', 'Unnamed: 52', 'Unnamed: 53', 'Unnamed: 54', 'Unnamed: 55', 'Unnamed: 59', 'Unnamed: 60'], 1)
df.head()
# Out:
#   States and Provinces        Unnamed: 1  Revised June 23, 2014  \
# 0             #isocode          Location  Expenditures-Academic
# 1                CA-AB           Alberta                    NaN
# 2                CA-BC  British Columbia                    NaN
# 3                CA-MB          Manitoba                    NaN
# 4                CA-NB     New Brunswick                    NaN
#
#                      Unnamed: 3                  Unnamed: 4  \
# 0  Expenditures-Academic-Source  Expenditures-Academic-Year
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
#
#             Unnamed: 8                  Unnamed: 9               Unnamed: 10  \
# 0  Expenditures-Public  Expenditures-Public-Source  Expenditures-Public-Year
# ...

# %%
df = df.drop(['Unnamed: 61', 'Unnamed: 62', 'Unnamed: 63', 'Unnamed: 64', 'Unnamed: 68', 'Unnamed: 69', 'Unnamed: 70', 'Unnamed: 74', 'Unnamed: 75', 'Unnamed: 76'], 1)
df.head()
# Out:
#   States and Provinces        Unnamed: 1  Revised June 23, 2014  \
# 0             #isocode          Location  Expenditures-Academic
# 1                CA-AB           Alberta                    NaN
# 2                CA-BC  British Columbia                    NaN
# 3                CA-MB          Manitoba                    NaN
# 4                CA-NB     New Brunswick                    NaN
#
#                      Unnamed: 3                  Unnamed: 4  \
# 0  Expenditures-Academic-Source  Expenditures-Academic-Year
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
#
#             Unnamed: 8                  Unnamed: 9               Unnamed: 10  \
# 0  Expenditures-Public  Expenditures-Public-Source  Expenditures-Public-Year
# ...

# %%
df.drop(df.columns[[0]], axis=1)
# Out:
#                    Unnamed: 1  Revised June 23, 2014  \
# 0                    Location  Expenditures-Academic
# 1                     Alberta                    NaN
# 2            British Columbia                    NaN
# 3                    Manitoba                    NaN
# 4               New Brunswick                    NaN
# 5                 Nova Scotia                    NaN
# 6                     Ontario                    NaN
# 7        Prince Edward Island                    NaN
# 8                      Quebec                    NaN
# 9                Saskatchewan                    NaN
# 10  Newfoundland and Labrador                    NaN
# 11      Northwest Territories                    NaN
# 12                    Nunavut                    NaN
# 13            Yukon Territory                    NaN
# 14                     Alaska              16173206
# 15                    Alabama              89004634
# 16                   Arkansas              45863634
# ...

# %%
#DELETINGCANADA
df.drop(1, inplace=True)
df.drop(2, inplace=True)
df.drop(3, inplace=True)
df.drop(4, inplace=True)
df.drop(5, inplace=True)
df.drop(6, inplace=True)
df.drop(7, inplace=True)
df.drop(8, inplace=True)
df.drop(9, inplace=True)
df.drop(10, inplace=True)
df.drop(11, inplace=True)
df.drop(12, inplace=True)
df.drop(13, inplace=True)
df.head()
# Out:
#    States and Provinces Unnamed: 1  Revised June 23, 2014  \
# 0              #isocode   Location  Expenditures-Academic
# 14                US-AK     Alaska              16173206
# 15                US-AL    Alabama              89004634
# 16                US-AR   Arkansas              45863634
# 17                US-AZ    Arizona              91558105
#
#                       Unnamed: 3                  Unnamed: 4  \
# 0   Expenditures-Academic-Source  Expenditures-Academic-Year
# 14                           33                        2012
# 15                           33                        2012
# 16                           33                        2012
# 17                           33                        2012
#
#              Unnamed: 8                  Unnamed: 9               Unnamed: 10  \
# 0   Expenditures-Public  Expenditures-Public-Source  Expenditures-Public-Year
# 14            35890655                          34                      2013
# ...

# %%
# %pylab inline
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /usr/local/lib/python3.6/dist-packages/IPython/core/magics/pylab.py:161: UserWarning: pylab import has clobbered these variables: ['polyfit']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
df.head()
# Out:
#    States and Provinces Unnamed: 1  Revised June 23, 2014  \
# 0              #isocode   Location  Expenditures-Academic
# 14                US-AK     Alaska              16173206
# 15                US-AL    Alabama              89004634
# 16                US-AR   Arkansas              45863634
# 17                US-AZ    Arizona              91558105
#
#                       Unnamed: 3                  Unnamed: 4  \
# 0   Expenditures-Academic-Source  Expenditures-Academic-Year
# 14                           33                        2012
# 15                           33                        2012
# 16                           33                        2012
# 17                           33                        2012
#
#              Unnamed: 8                  Unnamed: 9               Unnamed: 10  \
# 0   Expenditures-Public  Expenditures-Public-Source  Expenditures-Public-Year
# 14            35890655                          34                      2013
# ...

# %%
# %pylab inline
import pandas as pd
ThisData = df
ThisData.head()
sap = ['Unnamed: 1']
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
expenditure = ['Revised June 23, 2014']
p = plot(expenditure,sap,'o')
ax = gca()
xt = ax.set_xlabel('States')
yt = ax.set_ylabel('2012 Expenditures')

# %%
# %matplotlib inline
import pandas as pd

# %%
ThisData['Unnamed: 1'][0:5]
# Out:
# 0     Location
# 14      Alaska
# 15     Alabama
# 16    Arkansas
# 17     Arizona
# Name: Unnamed: 1, dtype: object

# %%
ThisData['Revised June 23, 2014'][0:5]
# Out:
# 0     Expenditures-Academic
# 14                16173206
# 15                89004634
# 16                45863634
# 17                91558105
# Name: Revised June 23, 2014, dtype: object

# %%
ThisData['Unnamed: 10'][0:5]
# Out:
# 0     Expenditures-Public-Year
# 14                       2013
# 15                       2013
# 16                       2013
# 17                       2013
# Name: Unnamed: 10, dtype: object

# %%
import matplotlib.pyplot as plt
import pandas as pd
plt.figure()
loansmin = df

sap = loansmin['Unnamed: 1']
p = sap.hist()

# %%
import matplotlib.pyplot as plt
import pandas as pd
plt.figure()

# %%
# importing the required module 
import matplotlib.pyplot as plt 
  
# x axis values 
x = [4586,8900,9093,9155] 
# corresponding y axis values 
y = [196,399,274,345] 


  
# plotting the points  
plt.plot(x, y) 
  
# naming the x axis 
plt.xlabel('Expenditure (x10,000)') 
# naming the y axis 
plt.ylabel('Number of Librarians') 
  
# giving a title to my graph 
plt.title('Librarians vs. Expenditures in Academic Libraries in 2012') 
  
# function to show the plot 
plt.show()

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
 
objects = ('Alaska', 'Arkansas', 'Arizona', 'DC')
y_pos = np.arange(len(objects))
performance = [16173206, 45863634,91558105,90934715]
 
plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('USD')
plt.title('Academic Expenditures 2012')
 
plt.show()

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
 
objects = ('Alaska', 'Arkansas', 'Arizona', 'DC')
y_pos = np.arange(len(objects))
performance = [35890655, 68924081, 174718983, 42644984 ]
 
plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('USD')
plt.title('Public Expenditures 2013')
 
plt.show()

# %%
import numpy as np

np.random.seed(1)

x = 16173206, 89004634, 45863634, 91558105, 714500925, 101328081, 152388676, 90934715, 26920185, 248938193, 176628408

# Positive Correlation with some noise
y = 35890655, 98137407, 68924081, 174718983, 1206002092, 256411052, 202345338, 42646984, 24304619, 511180506, 178653367

np.corrcoef(x, y)
# Out:
# array([[1.        , 0.98050451],
#        [0.98050451, 1.        ]])

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.style.use('ggplot')

plt.scatter(x, y)
plt.show()

# %%
import numpy as np

np.random.seed(1)

x = 48, 399, 196, 345, 2236, 326, 489, 274, 93, 1098, 799

# Positive Correlation with some noise
y = 109.47, 759.96, 264.28, 551.13, 3143.95, 864.73, 1108.24, 158, 115.55, 1912.1, 605
np.corrcoef(x, y)
# Out:
# array([[1.        , 0.95219292],
#        [0.95219292, 1.        ]])

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.style.use('ggplot')

plt.scatter(x, y)
plt.show()

# %%
import numpy as np

np.random.seed(1)

x = 738068, 4888949, 3020327, 7123898, 39776830, 

# Positive Correlation with some noise
y = 84, 221, 53, 85, 166
np.corrcoef(x, y)
# Out:
# array([[1.        , 0.38769543],
#        [0.38769543, 1.        ]])

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.style.use('ggplot')

plt.scatter(x, y)
plt.show()
